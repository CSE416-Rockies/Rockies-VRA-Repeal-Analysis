# %%
import pandas as pd

# %%
df = pd.read_csv('../Georgia/ga_raceblind_5000_summary.csv')

# %%
print(df.shape)
df.head()
# Out:
# (5000, 6)
#    plan_id  democrat_wins  republican_wins  minority_effective  \
# 0        0              5                9                   5
# 1        1              5                9                   5
# 2        2              5                9                   5
# 3        3              5                9                   5
# 4        4              4               10                   4
#
#    opportunity_districts   ensemble
# 0                      4  raceblind
# 1                      3  raceblind
# 2                      3  raceblind
# 3                      3  raceblind
# 4                      3  raceblind

# %%
democrat_win = (df['democrat_wins'] > df['republican_wins']).sum()
print(f'total of {democrat_win} democrat wins')
# Out:
# total of 1 democrat wins

# %%
minority_effective = df.groupby(['minority_effective']).size()
minority_effective
# Out:
# minority_effective
# 2     103
# 3    1228
# 4    2378
# 5    1160
# 6     131
# dtype: int64

# %%
opportunity_effective = df.groupby(['opportunity_districts']).size()
opportunity_effective
# Out:
# opportunity_districts
# 1     412
# 2    3314
# 3    1133
# 4     141
# dtype: int64
