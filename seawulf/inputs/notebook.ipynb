# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('ar_seawulf.gpkg')

# %%
gdf
# Out:
#                           Unique_ID COUNTYFP  Kamala D. Harris  \
# 0            05001-81 - Stuttgart 2      001               293
# 1         05001-36 - Gillett Ward 3      001                25
# 2               05001-53 - Dewitt 2      001                49
# 3               05001-51 - DeWitt 1      001               101
# 4               05001-55 - Dewitt 3      001                42
# ...                             ...      ...               ...
# 2676   05149-10 - Dardanelle Ward 3      149                59
# 2677          05149-18 - Magazine 1      149                79
# 2678          05149-29 - Ions Creek      149                 0
# 2679            05149-24 - Waveland      149                18
# 2680  05149-07 - Dardanelle Outside      149               246
#
#       Donald J. Trump  Other_candidates  Total_votes  White_population  \
# 0                 639                19          951        486.169395
# ...
