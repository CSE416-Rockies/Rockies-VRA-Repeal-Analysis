# %%
import pandas as pd
import numpy as np
import geopandas

# %%
df_de = geopandas.read_file("../data/Delaware/Precinct/de_nyt.geojson")
df_de = df_de.sort_values(by="GEOID")

columns_needed = ['GEOID', 'geometry']
de_precincts = df_de[columns_needed]
de_precincts['precinct'] = "Precinct " + df_de["GEOID"]
# Out:
# /Users/xinyuesu/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
de_precincts
# Out:
#            GEOID                                           geometry  \
# 0    10001-11-05  POLYGON ((-75.6658 39.29057, -75.66581 39.2905...
# 1    10001-11-06  POLYGON ((-75.75449 39.22743, -75.75449 39.227...
# 2    10001-11-07  POLYGON ((-75.69349 39.19968, -75.6935 39.1996...
# 3    10001-11-08  POLYGON ((-75.64732 39.15437, -75.64734 39.154...
# 4    10001-11-09  POLYGON ((-75.74776 39.14335, -75.74776 39.143...
# ..           ...                                                ...
# 520  10005-41-10  POLYGON ((-75.23551 38.48005, -75.23551 38.480...
# 521  10005-41-11  POLYGON ((-75.19192 38.47895, -75.19193 38.478...
# 522  10005-41-12  POLYGON ((-75.18948 38.48168, -75.18857 38.482...
# 523  10005-41-13  POLYGON ((-75.19192 38.47895, -75.19191 38.478...
# 524  10005-41-14  POLYGON ((-75.17737 38.53138, -75.17696 38.531...
#
#                  precinct
# 0    Precinct 10001-11-05
# 1    Precinct 10001-11-06
# 2    Precinct 10001-11-07
# 3    Precinct 10001-11-08
# ...

# %%
print(de_precincts.shape)
de_rows = len(de_precincts)
print(de_rows)
# Out:
# (526, 3)
# 526

# %%
de_precincts.loc[:, "total_population"] = np.random.randint(1000, 5001, size=de_rows)
de_precincts.loc[:, "latino_percentage"] = np.random.uniform(0,80, size=de_rows)
de_precincts.loc[:, "black_percentage"] = (100-de_precincts['latino_percentage'])*np.random.uniform(0, 1, size=de_rows)
de_precincts.loc[:, "other_percentage"] = (100 - de_precincts['latino_percentage'] - de_precincts['black_percentage'])

# %%
de_precincts
# Out:
#            GEOID                                           geometry  \
# 0    10001-11-05  POLYGON ((-75.6658 39.29057, -75.66581 39.2905...
# 1    10001-11-06  POLYGON ((-75.75449 39.22743, -75.75449 39.227...
# 2    10001-11-07  POLYGON ((-75.69349 39.19968, -75.6935 39.1996...
# 3    10001-11-08  POLYGON ((-75.64732 39.15437, -75.64734 39.154...
# 4    10001-11-09  POLYGON ((-75.74776 39.14335, -75.74776 39.143...
# ..           ...                                                ...
# 520  10005-41-10  POLYGON ((-75.23551 38.48005, -75.23551 38.480...
# 521  10005-41-11  POLYGON ((-75.19192 38.47895, -75.19193 38.478...
# 522  10005-41-12  POLYGON ((-75.18948 38.48168, -75.18857 38.482...
# 523  10005-41-13  POLYGON ((-75.19192 38.47895, -75.19191 38.478...
# 524  10005-41-14  POLYGON ((-75.17737 38.53138, -75.17696 38.531...
#
#                  precinct  total_population  latino_percentage  \
# 0    Precinct 10001-11-05              3920          60.470147
# ...

# %%
df_ga = geopandas.read_file("../data/Georgia/Precinct/ga_nyt.geojson")
ga_precincts = df_ga[columns_needed]
ga_precincts['precinct'] = "Precinct " + df_ga["GEOID"]
# Out:
# /Users/xinyuesu/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
print(ga_precincts.shape)
ga_rows = len(ga_precincts)
print(ga_rows)
# Out:
# (2680, 3)
# 2680

# %%
ga_precincts.loc[:, "total_population"] = np.random.randint(1000, 5001, size=ga_rows)
ga_precincts.loc[:, "latino_percentage"] = np.random.uniform(0,80, size=ga_rows)
ga_precincts.loc[:, "black_percentage"] = (100-ga_precincts['latino_percentage'])*np.random.uniform(0, 1, size=ga_rows)
ga_precincts.loc[:, "other_percentage"] = (100 - ga_precincts['latino_percentage'] - ga_precincts['black_percentage'])
# Out:
# /Users/xinyuesu/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/xinyuesu/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
# /Users/xinyuesu/Library/Python/3.9/lib/python/site-packages/geopandas/geodataframe.py:1819: SettingWithCopyWarning:
# ...

# %%
ga_precincts
# Out:
#          GEOID                                           geometry  \
# 0     13001-4B  POLYGON ((-82.31151 31.59099, -82.31149 31.590...
# 1     13001-5B  POLYGON ((-82.40153 31.69729, -82.40206 31.697...
# 2     13001-3C  POLYGON ((-82.13346 31.6308, -82.13346 31.6308...
# 3      13001-2  POLYGON ((-82.28049 31.84937, -82.2805 31.8493...
# 4     13001-1B  POLYGON ((-82.29335 31.94084, -82.29344 31.940...
# ...        ...                                                ...
# 2675  13321-01  POLYGON ((-83.99673 31.5398, -83.99672 31.5398...
# 2676  13321-09  POLYGON ((-83.79721 31.72736, -83.7972 31.7276...
# 2677  13321-03  POLYGON ((-83.73692 31.62228, -83.73693 31.622...
# 2678  13321-15  POLYGON ((-83.89245 31.64641, -83.89212 31.646...
# 2679  13321-14  POLYGON ((-83.99673 31.5398, -83.99673 31.5397...
#
#                precinct  total_population  latino_percentage  \
# 0     Precinct 13001-4B              2307          56.204642
# ...

# %%
print(ga_precincts['precinct'].isnull().sum())
print(de_precincts['precinct'].isnull().sum())
# Out:
# 0
# 0

# %%
de_precincts.to_file("Delaware_precincts.geojson", driver="GeoJSON")
ga_precincts.to_file("Georgia_precincts.geojson", driver="GeoJSON")

# %%
# !pip install geopandas topojson
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip

# %%
from topojson import Topology

# %%
gdf_ga = geopandas.read_file("Georgia_precincts.geojson")
gdf_de = geopandas.read_file("Delaware_precincts.geojson")

# %%
topology_ga = Topology(gdf_ga)
topology_de = Topology(gdf_de)
# Export TopoJSON
topology_ga.to_json("Georgia_precincts_topo.topojson")
topology_de.to_json("Delaware_precincts_topo.topojson")
